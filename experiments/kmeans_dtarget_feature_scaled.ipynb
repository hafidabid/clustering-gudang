# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from numpy import pi, sin,cos, arctan2, sqrt
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from kmeans2 import KMeansAlgorithm

# %%
flname="../dataset_cluster_warehouse_exp_2.csv"
df = pd.read_csv(flname)
df
# Out:
#     province_name                        city_name      district_name  \
# 0     DKI JAKARTA  KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG
# 1     DKI JAKARTA  KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG
# 2     DKI JAKARTA  KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG
# 3     DKI JAKARTA  KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG
# 4     DKI JAKARTA  KOTA ADMINISTRASI JAKARTA BARAT  GROGOL PETAMBURAN
# ..            ...                              ...                ...
# 185   DKI JAKARTA  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG
# 186   DKI JAKARTA  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG
# 187   DKI JAKARTA  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG
# 188   DKI JAKARTA  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG
# 189   DKI JAKARTA  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG
#
#      subdistrict_name                lat_long  avg_demand_baseline  \
# 0    CENGKARENG BARAT    -6.13727,106.7153587                   57
# 1    CENGKARENG TIMUR  -6.1385859,106.7293052                   33
# 2        DURI KOSAMBI  -6.1715044,106.7056503                   25
# 3          RAWA BUAYA  -6.1613339,106.7294525                   40
# 4              GROGOL   -6.159495,106.7897422                  153
# ..                ...                     ...                  ...
# 185      KAMPUNG BALI  -6.1852948,106.8073138                   45
# 186     KARET TENGSIN  -6.2076699,106.8075363                  240
# 187      KEBON KACANG  -6.1906249,106.8072637                   99
# 188      KEBON MELATI  -6.1968299,106.8074788                   37
# 189        PETAMBURAN  -6.1963744,106.7962523                  154
#
#      demand_target
# 0             85.5
# 1             49.5
# 2             37.5
# 3             60.0
# 4            229.5
# ..             ...
# 185           67.5
# 186          360.0
# 187          148.5
# 188           55.5
# 189          231.0
#
# [190 rows x 7 columns]

# %%
# add distancce in dataframe from current loc

data_lat = []
data_long = []
for idx, row in df.iterrows():
    point = row['lat_long'].split(',')
    lat = float(point[0])
    long = float(point[1])
    data_lat.append(lat)
    data_long.append(long)

df = df.assign(lat=data_lat, long=data_long)
dataset = df[['city_name', 'district_name', 'avg_demand_baseline', 'demand_target', 'lat', 'long']]
dataset
# Out:
#                            city_name      district_name  avg_demand_baseline  \
# 0    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   57
# 1    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   33
# 2    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   25
# 3    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   40
# 4    KOTA ADMINISTRASI JAKARTA BARAT  GROGOL PETAMBURAN                  153
# ..                               ...                ...                  ...
# 185  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                   45
# 186  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                  240
# 187  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                   99
# 188  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                   37
# 189  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                  154
#
#      demand_target       lat        long
# 0             85.5 -6.137270  106.715359
# 1             49.5 -6.138586  106.729305
# 2             37.5 -6.171504  106.705650
# 3             60.0 -6.161334  106.729452
# 4            229.5 -6.159495  106.789742
# ..             ...       ...         ...
# 185           67.5 -6.185295  106.807314
# 186          360.0 -6.207670  106.807536
# 187          148.5 -6.190625  106.807264
# 188           55.5 -6.196830  106.807479
# 189          231.0 -6.196374  106.796252
#
# [190 rows x 6 columns]

# %%
lat_lng_dataset = dataset[['lat', 'long']]
other_dataset = dataset[['demand_target']]

# %%
#Rescaling
scaler = StandardScaler()
scaled_dataset = scaler.fit_transform(other_dataset)
scaled_dataset = pd.DataFrame(scaled_dataset, columns=["demand_target"])
train_dataset = pd.concat([lat_lng_dataset, scaled_dataset],axis=1)
train_dataset
# Out:
#           lat        long  demand_target
# 0   -6.137270  106.715359      -0.434857
# 1   -6.138586  106.729305      -0.802533
# 2   -6.171504  106.705650      -0.925091
# 3   -6.161334  106.729452      -0.695294
# 4   -6.159495  106.789742       1.035845
# ..        ...         ...            ...
# 185 -6.185295  106.807314      -0.618695
# 186 -6.207670  106.807536       2.368669
# 187 -6.190625  106.807264       0.208575
# 188 -6.196830  106.807479      -0.741253
# 189 -6.196374  106.796252       1.051165
#
# [190 rows x 3 columns]

# %%
# Elbow method
wcss = []
crange = 10
for i in range(1, crange):
    kmeans = KMeans(n_clusters=i, init='random', random_state=50)
    kmeans.fit(train_dataset)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, crange), wcss)
plt.xlabel("number of cluster")
plt.ylabel("wcss")
plt.show()

# %%
cluster_final = 3
km = KMeans(n_clusters=cluster_final, init='random', random_state=50)
km.fit(train_dataset)
# Out:
# KMeans(init='random', n_clusters=3, random_state=50)

# %%
clusters = km.cluster_centers_
print(clusters)
# Out:
# [[ -6.21052476 106.8228269   -0.71061374]
#  [ -6.2137292  106.81625025   0.25520081]
#  [ -6.197611   106.80012263   2.13836156]]

# %%
y_km = km.fit_predict(train_dataset)
dataset = dataset.assign(pred=y_km)
dataset
# Out:
#                            city_name      district_name  avg_demand_baseline  \
# 0    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   57
# 1    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   33
# 2    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   25
# 3    KOTA ADMINISTRASI JAKARTA BARAT         CENGKARENG                   40
# 4    KOTA ADMINISTRASI JAKARTA BARAT  GROGOL PETAMBURAN                  153
# ..                               ...                ...                  ...
# 185  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                   45
# 186  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                  240
# 187  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                   99
# 188  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                   37
# 189  KOTA ADMINISTRASI JAKARTA PUSAT        TANAH ABANG                  154
#
#      demand_target       lat        long  pred
# 0             85.5 -6.137270  106.715359     0
# 1             49.5 -6.138586  106.729305     0
# 2             37.5 -6.171504  106.705650     0
# 3             60.0 -6.161334  106.729452     0
# 4            229.5 -6.159495  106.789742     1
# ..             ...       ...         ...   ...
# 185           67.5 -6.185295  106.807314     0
# 186          360.0 -6.207670  106.807536     2
# 187          148.5 -6.190625  106.807264     1
# 188           55.5 -6.196830  106.807479     0
# 189          231.0 -6.196374  106.796252     1
#
# [190 rows x 7 columns]

# %%
label_a = ("long",1)
label_b = ("lat", 0)
color_list = ["red", "green", "blue", "yellow", "pink", "orange", "purple"]
for i in range(cluster_final):
    plt.scatter(train_dataset[y_km==i][label_a[0]], train_dataset[y_km==i][label_b[0]], s=50, color=color_list[i%len(color_list)])
    plt.scatter(clusters[i][label_a[1]], clusters[i][label_b[1]], marker="*", s=200, color="black")

plt.show()

# %%
#Silhoutte Score
s_score = silhouette_score(train_dataset, km.labels_, metric='euclidean')
print("sihoute score is ", s_score)
# Out:
# sihoute score is  0.5582235324275799
